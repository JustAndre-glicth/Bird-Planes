# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np
from matplotlib import cm
import matplotlib.colors as col
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
# For scaling data
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import kneighbors_graph

# %%
df = pd.read_csv('/content/drive/MyDrive/PTDataScience/PandasForDataManipulation/birds.csv')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (9,12,15,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Record ID  Incident Year  ...  Other Strike  Other Damage
# 0          127128           1990  ...             0             0
# 1          129779           1990  ...             1             0
# 2          129780           1990  ...             0             0
# 3            2258           1990  ...             0             0
# 4            2257           1990  ...             0             0
# ...           ...            ...  ...           ...           ...
# 174099     366091           2015  ...             0             0
# 174100     365902           2015  ...             0             0
# 174101     365903           2015  ...             0             0
# ...

# %%
df['Species Name'] = df['Species Name'].fillna(method='ffill').fillna(method='bfill')

# %%
df['Species Name'].isnull().sum()
# Out:
# 0

# %%
df['Visibility'] = df['Visibility'].fillna(method='ffill').fillna(method='bfill')

# %%
df['Visibility'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # New DataFrame:

# %%
df
# Out:
#         Record ID  Incident Year  ...  Other Strike  Other Damage
# 0          127128           1990  ...             0             0
# 1          129779           1990  ...             1             0
# 2          129780           1990  ...             0             0
# 3            2258           1990  ...             0             0
# 4            2257           1990  ...             0             0
# ...           ...            ...  ...           ...           ...
# 174099     366091           2015  ...             0             0
# 174100     365902           2015  ...             0             0
# 174101     365903           2015  ...             0             0
# 174102     366046           2015  ...             0             0
# 174103     365823           2015  ...             1             0
#
# [174104 rows x 66 columns]

# %%
df['Precipitation'].value_counts()
# Out:
# NONE               80512
# RAIN                5270
# FOG                 1952
# SNOW                 313
# FOG, RAIN            239
# RAIN, SNOW            19
# FOG, SNOW             12
# FOG, RAIN, SNOW        5
# Name: Precipitation, dtype: int64

# %%
df['Precipitation']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 174099    NONE
# 174100    NONE
# 174101    NONE
# 174102    NONE
# 174103    NONE
# Name: Precipitation, Length: 174104, dtype: object

# %%
df['Flight Impact'] = df['Flight Impact'].fillna(method='ffill').fillna(method='bfill')

# %%
df
# Out:
#         Record ID  Incident Year  ...  Other Strike  Other Damage
# 0          127128           1990  ...             0             0
# 1          129779           1990  ...             1             0
# 2          129780           1990  ...             0             0
# 3            2258           1990  ...             0             0
# 4            2257           1990  ...             0             0
# ...           ...            ...  ...           ...           ...
# 174099     366091           2015  ...             0             0
# 174100     365902           2015  ...             0             0
# 174101     365903           2015  ...             0             0
# 174102     366046           2015  ...             0             0
# 174103     365823           2015  ...             1             0
#
# [174104 rows x 66 columns]

# %%
df['Engine3 Position'].isnull().sum()
# Out:
# 162445

# %% [markdown]
# # Dealing with the missing data!

# %%
df = df.fillna(method='ffill').fillna(method='bfill')

# %%
df
# Out:
#         Record ID  Incident Year  ...  Other Strike  Other Damage
# 0          127128           1990  ...             0             0
# 1          129779           1990  ...             1             0
# 2          129780           1990  ...             0             0
# 3            2258           1990  ...             0             0
# 4            2257           1990  ...             0             0
# ...           ...            ...  ...           ...           ...
# 174099     366091           2015  ...             0             0
# 174100     365902           2015  ...             0             0
# 174101     365903           2015  ...             0             0
# 174102     366046           2015  ...             0             0
# 174103     365823           2015  ...             1             0
#
# [174104 rows x 66 columns]

# %%
df.describe()
# Out:
#            Record ID  Incident Year  ...   Other Strike   Other Damage
# count  174104.000000  174104.000000  ...  174104.000000  174104.000000
# mean   241204.036915    2006.036392  ...       0.090727       0.008989
# std     94013.682213       6.747708  ...       0.287222       0.094383
# min      1000.000000    1990.000000  ...       0.000000       0.000000
# 25%    205411.750000    2001.000000  ...       0.000000       0.000000
# 50%    249102.500000    2007.000000  ...       0.000000       0.000000
# 75%    322592.250000    2012.000000  ...       0.000000       0.000000
# max    367445.000000    2015.000000  ...       1.000000       1.000000
#
# [8 rows x 44 columns]

# %%
df=df.replace('-','',regex=True)

# %%
df=df.replace('Over 100','',regex=True)

# %% [markdown]
# # Decision Tree:

# %%
X = df.loc[:, ['Speed',
           'Distance',
           'Height',
           'Aircraft Damage',
           'Windshield Strike',
           'Windshield Damage',
           'Engine1 Damage',
           'Nose Damage',
           'Tail Damage',
           'Wing or Rotor Damage',
           'Engine Ingested']]

# %%
X.shape
# Out:
# (174104, 11)

# %%
y = df.loc[:, 'Species Name'].values

# %%
y.shape
# Out:
# (174104,)

# %%
scaler = StandardScaler()
#fit
scaler.fit(X)
#transform Xx
X = scaler.transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.99, random_state=0, stratify=None )

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=2, splitter='random', max_features ='auto')
clf = clf.fit(X, y)

# %%
clf.predict(X_test)
# Out:
# array(['UNKNOWN MEDIUM BIRD', 'UNKNOWN MEDIUM BIRD', 'UNKNOWN SMALL BIRD',
#        ..., 'UNKNOWN MEDIUM BIRD', 'UNKNOWN MEDIUM BIRD',
#        'UNKNOWN MEDIUM BIRD'], dtype=object)

# %%
clf.predict_proba(X_test)
# Out:
# array([[3.55469611e-05, 6.39845300e-05, 7.10939222e-06, ...,
#         0.00000000e+00, 1.91953590e-03, 1.42187844e-05],
#        [3.55469611e-05, 6.39845300e-05, 7.10939222e-06, ...,
#         0.00000000e+00, 1.91953590e-03, 1.42187844e-05],
#        [0.00000000e+00, 8.30116631e-05, 0.00000000e+00, ...,
#         4.15058316e-05, 6.22587474e-04, 4.15058316e-05],
#        ...,
#        [3.55469611e-05, 6.39845300e-05, 7.10939222e-06, ...,
#         0.00000000e+00, 1.91953590e-03, 1.42187844e-05],
#        [3.55469611e-05, 6.39845300e-05, 7.10939222e-06, ...,
#         0.00000000e+00, 1.91953590e-03, 1.42187844e-05],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 5.40190147e-04, 1.08038029e-04]])

# %%
plt.figure(figsize=(15,15)); 
tree.plot_tree(clf,fontsize=10, filled=True);

# %%
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array(['UNKNOWN MEDIUM BIRD', 'UNKNOWN MEDIUM BIRD', 'UNKNOWN SMALL BIRD',
#        ..., 'UNKNOWN MEDIUM BIRD', 'UNKNOWN MEDIUM BIRD',
#        'UNKNOWN MEDIUM BIRD'], dtype=object)

# %%
clf.score(X_test, y_pred)
# Out:
# 1.0

# %%
from sklearn import metrics
print("Accuracy:",metrics.balanced_accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.0015029253471151513
